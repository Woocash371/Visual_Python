# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.set()

# %%
fig = plt.figure()

# %%
fig.show()
# Out:
# C:\Users\lukas\AppData\Local\Temp\ipykernel_17416\463783792.py:1: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
_ = plt.plot([0,1],[0,3])

# %%
_ = plt.plot([0,1],[0,3], label = 'line', color = 'green')

# %%
plt.plot([0,1,2],[0,3,2], label = 'line', color = 'green')
plt.xlabel('oś X')
plt.ylabel('oś y')
plt.title('Wykres')
_ = plt.legend()

# %%
x = np.arange(-3,3,0.1)
x_sin = np.sin(x)
x_cos = np.cos(x)
plt.plot(x,x_sin)
plt.plot(x,x_cos)

# %%
plt.subplot(121)
plt.plot([0,1,2], [3,2,5])
plt.subplot(122)
plt.plot([0,1,2], [1,2,1], 'r--')

# %%
fig = plt.figure(figsize = (12, 8))
plt.subplot(131)
plt.plot([0,1,2], [3,2,5])
plt.subplot(132)
plt.plot([0,1,2], [1,2,1], 'r--')
plt.subplot(133)
plt.plot([0,1,2], [3,6,1], 'ro')

# %% [markdown]
# Wykres słupkowe

# %%
plt.bar(x=[0, 1, 2, 3], height=[1.1, 3.2, 1.2, 2.4])
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(y=['a', 'b', 'c', 'd'], width=[1.1, 3.2, 1.2, 2.4])
# Out:
# <BarContainer object of 4 artists>

# %%
x1 = np.random.randn(300)
x2 = np.random.randn(300)

plt.scatter(x=x1, y=x2,)

# %%
x1 = np.random.randn(300)
x2 = np.random.randn(300)
x3 = np.random.randn(300) * 50 
plt.scatter(x=x1, y=x2, s=x3, alpha=0.5)
# Out:
# c:\Users\lukas\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\collections.py:967: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
