# %%
import pandas as pd
from enum import IntEnum
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import numpy as np
import datetime
import matplotlib.dates as mdates
from matplotlib.ticker import AutoMinorLocator
df = pd.read_excel("Chłodziarki ads.xlsx")
df.head()


df_3= df[df["IDc"] == 3] 
df_3_15 = df_3[df_3["IDa"] == 15]

df_3= df[df["IDc"] == 3] 
df_3_5 = df_3[df_3["IDa"] == 5]

df_2= df[df["IDc"] == 2] 
df_2_5 = df_2[df_2["IDa"] == 5]

df_2= df[df["IDc"] == 2] 
df_2_15 = df_2[df_2["IDa"] == 15]

df_1= df[df["IDc"] == 1] 


df_3_15_1 = df_3_15.iloc[0:3041]
df_3_15_2 = df_3_15.iloc[3041:6082]
df_3_5_1 = df_3_5.iloc[0:3041]
df_3_5_2 = df_3_5.iloc[3041:6082]


df_2_15_1 = df_2_15.iloc[0:3041]
df_2_15_2 = df_2_15.iloc[3041:6082]
df_2_5_1 = df_2_5.iloc[0:3041]
df_2_5_2 = df_2_5.iloc[3041:6082]


df_1_1 = df_1.iloc[0:3041]
df_1_2 = df_1.iloc[3041:6082]

df_1_1.describe()

lista = [df_3_15_1, df_3_15_2, df_3_5_1, df_3_5_2, df_2_15_1, df_2_15_2, df_2_5_1, df_2_5_2, df_1_1, df_1_2

]
# Out:
#                 t         Pads        Pevap  Pads1(-2mbar)  Pads2(-5mbar)  \
# count  3041.00000  3041.000000  3041.000000    3041.000000    3041.000000
# mean   1520.00000    16.274244    22.870504      14.274244      11.274244
# std     878.00541     3.317172     0.183813       3.317172       3.317172
# min       0.00000    11.604695    22.420014       9.604695       6.604695
# 25%     760.00000    13.296657    22.748116      11.296657       8.296657
# 50%    1520.00000    15.664281    22.871632      13.664281      10.664281
# 75%    2280.00000    19.107684    22.988960      17.107684      14.107684
# max    3040.00000    22.201051    23.329753      20.201051      17.201051
#
#        Pads3(+2mbar)  Pads4(+5mbar)  Pevap1(-2mbar)  Pevap2(-5mbar)  \
# count    3041.000000    3041.000000     3041.000000     3041.000000
# mean       18.274244      21.274244       20.870504       17.870504
# std         3.317172       3.317172        0.183813        0.183813
# ...

# %%
lista = [df_3_15_1, df_3_15_2, df_3_5_1, df_3_5_2, df_2_15_1, df_2_15_2, df_2_5_1, df_2_5_2, df_1_1, df_1_2]

# %%
for element in lista:
    rodzaj_materialu = element
    pevap = rodzaj_materialu['Pevap']
    pads = rodzaj_materialu['Pads']
    t = rodzaj_materialu['t']
    fig ,ax1 = plt.subplots()

    ax1.plot(t, pevap)
    ax1.plot(t, pads)
    ax1.set_title(tytul)
