# %%
import pandas as pd
from enum import IntEnum
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import numpy as np
import datetime
import matplotlib.dates as mdates
from matplotlib.ticker import AutoMinorLocator
df = pd.read_excel("Chlodziarki ads.xlsx")
df.head()
# Out:
#    t       Pads      Pevap  Pads1(-2mbar)  Pads2(-5mbar)  Pads3(+2mbar)  \
# 0  0  12.297552  25.901674      10.297552       7.297552      14.297552
# 1  1  13.754778  25.682053      11.754778       8.754778      15.754778
# 2  2  15.167928  25.515988      13.167928      10.167928      17.167928
# 3  3  16.376885  25.413141      14.376885      11.376885      18.376885
# 4  4  17.481574  25.331754      15.481574      12.481574      19.481574
#
#    Pads4(+5mbar)  Pevap1(-2mbar)  Pevap2(-5mbar)  Pevap3(+2mbar)  ...  \
# 0      17.297552       23.901674       20.901674       27.901674  ...
# 1      18.754778       23.682053       20.682053       27.682053  ...
# 2      20.167928       23.515988       20.515988       27.515988  ...
# 3      21.376885       23.413141       20.413141       27.413141  ...
# 4      22.481574       23.331754       20.331754       27.331754  ...
#
#    m7 (V3 (O - 60 s; Z - 270))  m8 (V4 (O - 60 s; Z - 330)  \
# ...

# %%
plt.figure(figsize = (8,10))

""" Pierwszy wykres"""
plt.subplot(3, 1, 1)
plt.plot(df_1_1["t"], df_1_1["m"], 
         label = "m")
plt.plot(df_1_1["t"], df_1_1["m16 (Padas -2mbar)"],
         label = "m1 (Padas -2mbar)")

plt.ylabel('masa pochłoniętej pary - m')
plt.yticks(np.arange(0, 2, 0.2))
plt.xticks(np.arange(0, 3100, 200))
plt.grid()
plt.legend()
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.05),
          ncol=3, fancybox=True, shadow=True)

"""
Drugi Wykres"""

plt.subplot(3, 1, 2)
plt.plot(df_1_1["t"], df_1_1['Pads4(+5mbar)'], label = "Pevap1(+5mbar)" )
plt.plot(df_1_1["t"], df_1_1['Pads1(-2mbar)'], label = 'Pads1(-2mbar)')
plt.plot(df_1_1["t"], df_1_1['Pevap'] )
plt.plot(df_1_1["t"], df_1_1['Pads'])
plt.xticks(np.arange(0, 3100, 200))
plt.yticks(np.arange(8, 30, 2))
plt.ylabel('Ciśnienie - p')
plt.grid()
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.05),
          ncol=3, fancybox=True, shadow=True)


"""Trzecie wykres
"""
plt.subplot(3, 1, 3)         
plt.plot(df_1_1["t"], df_1_1["V"])
plt.xticks(np.arange(0, 3100, 200))
plt.yticks(np.arange(0, 600, 500))

plt.grid()
plt.xlabel("Czas = t")

#plt.savefig("Wykres ID= 1 dla Pevap(+5mbar)", dpi = 150)
plt.show()

# %%
def wykres_masy(os_x = df_1_1["t"], os_y1 = df_1_1["m"], os_y2 = df_1_1["m"],
zapis_wykresu = "n", label2 = "wykres"):
    plt.figure(figsize = (10,8))
    plt.plot(os_x, os_y1, label = 'm')
    plt.plot(os_x, os_y2, label = label2)
    plt.ylabel('masa pochłoniętej pary - m')
    plt.yticks(np.arange(0, 2, 0.2))
    plt.xticks(np.arange(0, 3100, 200))
    plt.xlabel(' Czas - t')
    plt.grid()
    plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.05),
          ncol=3, fancybox=True, shadow=True)
    if zapis_wykresu == "y":
        plt.savefig(input("Wpis nazwę pod jaką chcesz zapisać: "), dpi = 150)
        plt.show()
    else:
        plt.show()

# %%
def wykres_cisnienia(os_x = df_1_1["t"], os_y1 = df_1_1["Pads"] , os_y2 = df_1_1["Pads"], os_y3 = df_1_1["Pevap"], 
                     os_y4 = df_1_1["Pevap"], legenda1 = "NaN" , legenda2 = "NaN", legenda3 = "NaN", legenda4 = "NaN"
):
    plt.figure(figsize = (10,8))
    plt.plot(os_x, os_y1, label = legenda1)
    plt.plot(os_x, os_y2, label = legenda2)
    plt.plot(os_x, os_y3, label = legenda3)
    plt.plot(os_x, os_y4, label = legenda4)
    plt.xticks(np.arange(0, 3100, 200))
    plt.yticks(np.arange(8, 30, 2))
    plt.ylabel('Ciśnienie - p')
    plt.grid()
    plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.05),
          ncol=3, fancybox=True, shadow=True)

# %%
wykres_masy(os_y2= df_2_5_1['m2(-5mbar)'], os_y1=df_2_5_1['m'])

# %%
"""Zmienna dla wszystkich predycji SilicaGelu"""


df_1_1_masa = [df_1_1['m'], df_1_1['m2(-5mbar)'],
               df_1_1['m3(+2mbar)'],df_1_1['m4(+5mbar)'],
               df_1_1['m5 (V1 (O - 45 s; Z - 270))'], df_1_1['m6 (V2 (O - 45 s; Z - 300))'],
               df_1_1['m7 (V3 (O - 60 s; Z - 270))'], df_1_1['m8 (V4 (O - 60 s; Z - 330)'], 
               df_1_1['m9 ( V5 (O - 75 s; Z - 300))'], df_1_1['m10 (V6 (O - 75 s; Z - 330))'],
               df_1_1['m11 (Pevap +2mbar)'], df_1_1['m12 (Pevap + 5mbar)'], 
               df_1_1['m13 (Pevap - 2mbar)'], df_1_1['m14 (Pads +2mbar)'],
               df_1_1['m15 (Pads +5mbar)'], df_1_1['m16 (Padas -2mbar)']]

# %%
"""Zmienna dla wszystkich predycji SilicaGelu"""


df_1_2_masa = [df_1_2['m'], df_1_2['m2(-5mbar)'],
               df_1_2['m3(+2mbar)'],df_1_2['m4(+5mbar)'],
               df_1_2['m5 (V1 (O - 45 s; Z - 270))'], df_1_2['m6 (V2 (O - 45 s; Z - 300))'],
               df_1_2['m7 (V3 (O - 60 s; Z - 270))'], df_1_2['m8 (V4 (O - 60 s; Z - 330)'], 
               df_1_2['m9 ( V5 (O - 75 s; Z - 300))'], df_1_2['m10 (V6 (O - 75 s; Z - 330))'],
               df_1_2['m11 (Pevap +2mbar)'], df_1_2['m12 (Pevap + 5mbar)'], 
               df_1_2['m13 (Pevap - 2mbar)'], df_1_2['m14 (Pads +2mbar)'],
               df_1_2['m15 (Pads +5mbar)'], df_1_2['m16 (Padas -2mbar)']]

# %%
"""Zmienna dla wszystkich predycji SilicaGelu oraz Aluminium 15%"""


df_2_15_1_masa = [df_2_15_1['m'], df_2_15_1['m2(-5mbar)'],
               df_2_15_1['m3(+2mbar)'],df_2_15_1['m4(+5mbar)'],
               df_2_15_1['m5 (V1 (O - 45 s; Z - 270))'], df_2_15_1['m6 (V2 (O - 45 s; Z - 300))'],
               df_2_15_1['m7 (V3 (O - 60 s; Z - 270))'], df_2_15_1['m8 (V4 (O - 60 s; Z - 330)'], 
               df_2_15_1['m9 ( V5 (O - 75 s; Z - 300))'], df_2_15_1['m10 (V6 (O - 75 s; Z - 330))'],
               df_2_15_1['m11 (Pevap +2mbar)'], df_2_15_1['m12 (Pevap + 5mbar)'], 
               df_2_15_1['m13 (Pevap - 2mbar)'], df_2_15_1['m14 (Pads +2mbar)'],
               df_2_15_1['m15 (Pads +5mbar)'], df_2_15_1['m16 (Padas -2mbar)']]

# %%
"""Zmienna dla wszystkich predycji SilicaGelu oraz Aluminium 15%"""

df_2_15_2_masa = [df_2_15_2['m'], df_2_15_2['m2(-5mbar)'],
               df_2_15_2['m3(+2mbar)'],df_2_15_2['m4(+5mbar)'],
               df_2_15_2['m5 (V1 (O - 45 s; Z - 270))'], df_2_15_2['m6 (V2 (O - 45 s; Z - 300))'],
               df_2_15_2['m7 (V3 (O - 60 s; Z - 270))'], df_2_15_2['m8 (V4 (O - 60 s; Z - 330)'], 
               df_2_15_2['m9 ( V5 (O - 75 s; Z - 300))'], df_2_15_2['m10 (V6 (O - 75 s; Z - 330))'],
               df_2_15_2['m11 (Pevap +2mbar)'], df_2_15_2['m12 (Pevap + 5mbar)'], 
               df_2_15_2['m13 (Pevap - 2mbar)'], df_2_15_2['m14 (Pads +2mbar)'],
               df_2_15_2['m15 (Pads +5mbar)'], df_2_15_2['m16 (Padas -2mbar)']]

# %%
"""Zmienna dla wszystkich predycji SilicaGelu oraz Aluminium 5%"""


df_2_5_1_masa = [df_2_5_1['m'], df_2_5_1['m2(-5mbar)'],
               df_2_5_1['m3(+2mbar)'],df_2_5_1['m4(+5mbar)'],
               df_2_5_1['m5 (V1 (O - 45 s; Z - 270))'], df_2_5_1['m6 (V2 (O - 45 s; Z - 300))'],
               df_2_5_1['m7 (V3 (O - 60 s; Z - 270))'], df_2_5_1['m8 (V4 (O - 60 s; Z - 330)'], 
               df_2_5_1['m9 ( V5 (O - 75 s; Z - 300))'], df_2_5_1['m10 (V6 (O - 75 s; Z - 330))'],
               df_2_5_1['m11 (Pevap +2mbar)'], df_2_5_1['m12 (Pevap + 5mbar)'], 
               df_2_5_1['m13 (Pevap - 2mbar)'], df_2_5_1['m14 (Pads +2mbar)'],
               df_2_5_1['m15 (Pads +5mbar)'], df_2_5_1['m16 (Padas -2mbar)']]

# %%
"""Zmienna dla wszystkich predycji SilicaGelu oraz Aluminium 5%"""



df_2_5_2_masa = [df_2_5_2['m'], df_2_5_2['m2(-5mbar)'],
               df_2_5_2['m3(+2mbar)'],df_2_5_2['m4(+5mbar)'],
               df_2_5_2['m5 (V1 (O - 45 s; Z - 270))'], df_2_5_2['m6 (V2 (O - 45 s; Z - 300))'],
               df_2_5_2['m7 (V3 (O - 60 s; Z - 270))'], df_2_5_2['m8 (V4 (O - 60 s; Z - 330)'], 
               df_2_5_2['m9 ( V5 (O - 75 s; Z - 300))'], df_2_5_2['m10 (V6 (O - 75 s; Z - 330))'],
               df_2_5_2['m11 (Pevap +2mbar)'], df_2_5_2['m12 (Pevap + 5mbar)'], 
               df_2_5_2['m13 (Pevap - 2mbar)'], df_2_5_2['m14 (Pads +2mbar)'],
               df_2_5_2['m15 (Pads +5mbar)'], df_2_5_2['m16 (Padas -2mbar)']]

# %%
"""Zmienna dla wszystkich predycji SilicaGelu oraz NC 5%"""



df_3_5_1_masa = [df_3_5_1['m'], df_3_5_1['m2(-5mbar)'],
               df_3_5_1['m3(+2mbar)'],df_3_5_1['m4(+5mbar)'],
               df_3_5_1['m5 (V1 (O - 45 s; Z - 270))'], df_3_5_1['m6 (V2 (O - 45 s; Z - 300))'],
               df_3_5_1['m7 (V3 (O - 60 s; Z - 270))'], df_3_5_1['m8 (V4 (O - 60 s; Z - 330)'], 
               df_3_5_1['m9 ( V5 (O - 75 s; Z - 300))'], df_3_5_1['m10 (V6 (O - 75 s; Z - 330))'],
               df_3_5_1['m11 (Pevap +2mbar)'], df_3_5_1['m12 (Pevap + 5mbar)'], 
               df_3_5_1['m13 (Pevap - 2mbar)'], df_3_5_1['m14 (Pads +2mbar)'],
               df_3_5_1['m15 (Pads +5mbar)'], df_3_5_1['m16 (Padas -2mbar)']]

# %%
"""Zmienna dla wszystkich predycji SilicaGelu oraz NC 5%"""


df_3_5_2_masa = [df_3_5_2['m'], df_3_5_2['m2(-5mbar)'],
               df_3_5_2['m3(+2mbar)'],df_3_5_2['m4(+5mbar)'],
               df_3_5_2['m5 (V1 (O - 45 s; Z - 270))'], df_3_5_2['m6 (V2 (O - 45 s; Z - 300))'],
               df_3_5_2['m7 (V3 (O - 60 s; Z - 270))'], df_3_5_2['m8 (V4 (O - 60 s; Z - 330)'], 
               df_3_5_2['m9 ( V5 (O - 75 s; Z - 300))'], df_3_5_2['m10 (V6 (O - 75 s; Z - 330))'],
               df_3_5_2['m11 (Pevap +2mbar)'], df_3_5_2['m12 (Pevap + 5mbar)'], 
               df_3_5_2['m13 (Pevap - 2mbar)'], df_3_5_2['m14 (Pads +2mbar)'],
               df_3_5_2['m15 (Pads +5mbar)'], df_3_5_2['m16 (Padas -2mbar)']]

# %%
"""Zmienna dla wszystkich predycji SilicaGelu oraz NC 15%"""


df_3_15_1_masa = [df_3_15_1['m'], df_3_15_1['m2(-5mbar)'],
               df_3_15_1['m3(+2mbar)'],df_3_15_1['m4(+5mbar)'],
               df_3_15_1['m5 (V1 (O - 45 s; Z - 270))'], df_3_15_1['m6 (V2 (O - 45 s; Z - 300))'],
               df_3_15_1['m7 (V3 (O - 60 s; Z - 270))'], df_3_15_1['m8 (V4 (O - 60 s; Z - 330)'], 
               df_3_15_1['m9 ( V5 (O - 75 s; Z - 300))'], df_3_15_1['m10 (V6 (O - 75 s; Z - 330))'],
               df_3_15_1['m11 (Pevap +2mbar)'], df_3_15_1['m12 (Pevap + 5mbar)'], 
               df_3_15_1['m13 (Pevap - 2mbar)'], df_3_15_1['m14 (Pads +2mbar)'],
               df_3_15_1['m15 (Pads +5mbar)'], df_3_15_1['m16 (Padas -2mbar)']]

# %%
"""Zmienna dla wszystkich predycji SilicaGelu oraz NC 15%"""

df_3_15_2_masa = [df_3_15_2['m'], df_3_15_2['m2(-5mbar)'],
               df_3_15_2['m3(+2mbar)'],df_3_15_2['m4(+5mbar)'],
               df_3_15_2['m5 (V1 (O - 45 s; Z - 270))'], df_3_15_2['m6 (V2 (O - 45 s; Z - 300))'],
               df_3_15_2['m7 (V3 (O - 60 s; Z - 270))'], df_3_15_2['m8 (V4 (O - 60 s; Z - 330)'], 
               df_3_15_2['m9 ( V5 (O - 75 s; Z - 300))'], df_3_15_2['m10 (V6 (O - 75 s; Z - 330))'],
               df_3_15_2['m11 (Pevap +2mbar)'], df_3_15_2['m12 (Pevap + 5mbar)'], 
               df_3_15_2['m13 (Pevap - 2mbar)'], df_3_15_2['m14 (Pads +2mbar)'],
               df_3_15_2['m15 (Pads +5mbar)'], df_3_15_2['m16 (Padas -2mbar)']]

# %%
"Wykresy masy"

for i in df_1_1_masa:
    wykres_masy(os_y2= i, os_y1= df_1_1_masa[0], label2= print(i), zapis_wykresu= 'n')
    +
