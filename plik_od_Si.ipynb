# %%
import pandas as pd
from sklearn.datasets import make_regression

# Wygeneruj losowy zestaw danych regresji liniowej
X, y = make_regression(n_samples=100, n_features=1, noise=0.1)

# Utwórz ramkę danych Pandas z danych
df = pd.DataFrame({"x": X[:, 0], "y": y})

print(df)
# Out:
#            x           y
# 0   1.547185  102.224756
# 1  -0.166272  -10.761185
# 2   1.628305  107.690267
# 3  -0.062126   -4.060309
# 4   0.715726   47.192653
# ..       ...         ...
# 95 -0.008531   -0.371607
# 96  1.865287  123.242622
# 97 -0.284180  -18.822221
# 98 -1.067255  -70.543108
# 99 -0.342455  -22.588631
#
# [100 rows x 2 columns]

# %%
import pandas as pd
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt

# Wygeneruj losowy zestaw danych regresji liniowej
X, y = make_regression(n_samples=100, n_features=1, noise=0.1)

# Utwórz ramkę danych Pandas z danych
df = pd.DataFrame({"x": X[:, 0], "y": y})

# Statystyka opisowa
print(df.describe())

# Wizualizacja danych
plt.scatter(df["x"], df["y"])
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# Obliczenie korelacji między zmiennymi
print(df["x"].corr(df["y"]))
# Out:
#                 x           y
# count  100.000000  100.000000
# mean    -0.026800   -2.408134
# std      1.059323   95.027294
# min     -2.701251 -242.385498
# 25%     -0.704326  -63.295851
# 50%     -0.093720   -8.450121
# 75%      0.651417   58.308402
# max      3.516624  315.293519
# 0.999999452043381
